# %%
# Out:
# Cleaned dataset size: 23155

# %%
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              WellBeing   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     25.99
# Date:                Mon, 12 Jan 2026   Prob (F-statistic):           8.71e-50
# Time:                        15:27:17   Log-Likelihood:                -49464.
# No. Observations:               23155   AIC:                         9.895e+04
# Df Residuals:                   23144   BIC:                         9.904e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                                                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_10912\2846916831.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.lineplot(data=df_clean, x='Age', y='WellBeing', hue='Sex',

# %%
# Out:
# PD030
# 1    20568
# 2     1463
# 3     1124
# Name: count, dtype: int64

# %%
# Out:
# --- Extended Regression Results ---
#                             OLS Regression Results
# ...
# Dep. Variable:               Life_Sat   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     31.07
# Date:                Mon, 12 Jan 2026   Prob (F-statistic):           3.60e-43
# Time:                        15:40:59   Log-Likelihood:                -51997.
# No. Observations:               24322   AIC:                         1.040e+05
# Df Residuals:                   24314   BIC:                         1.041e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ...
